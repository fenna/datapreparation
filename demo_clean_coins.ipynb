# %% [markdown]
# # Demo notebook cleaning scraped data
#
# From the website https://www.coingecko.com data was scraped. The data are all strings, due to the scraping and contains some unwanted characters. This notebook demonstrates some regular cleaning steps

# %%
import pandas as pd
import numpy as np

# %%
#read the file
colnames = ['x','Coin', 'Price','1h','24h','7d', '24Volume', 'Mkt Cap', 'FDV', 'MarktcapFDV', 'x3']
df = pd.read_csv('../Coin.csv', names=colnames, skiprows=1).reset_index()

# %%
#check the file
df.head()
# Out:
#    level_0  level_1  x           Coin       Price     1h    24h     7d  \
# 0        0      NaN  1    Bitcoin BTC  $28,919.33   0.0%  -1.5%  -3.3%
# 1        1      NaN  2   Ethereum ETH   $1,954.65   0.2%  -2.4%   1.8%
# 2        2      NaN  3    Tether USDT       $1.00  -0.1%  -0.4%  -0.1%
# 3        3      NaN  4        BNB BNB     $325.55   0.1%  -1.2%   1.6%
# 4        4      NaN  5  USD Coin USDC   $0.999955  -0.0%  -0.5%   0.0%
#
#           24Volume           Mkt Cap               FDV MarktcapFDV  x3
# 0  $23,383,926,918  $559,386,921,097  $607,040,903,953        0.92 NaN
# 1  $15,145,886,450  $235,267,461,213  $235,267,461,213        1.00 NaN
# 2  $39,351,843,271   $81,374,101,359   $81,374,101,359        1.00 NaN
# 3     $926,550,242   $51,369,472,670   $65,071,483,944        0.79 NaN
# 4   $5,052,260,808   $31,248,083,356   $31,248,083,356        1.00 NaN

# %%
#remove colums
df = df.iloc[:,3:-1]

# %%
#check datatypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Coin         100 non-null    object
#  1   Price        100 non-null    object
#  2   1h           100 non-null    object
#  3   24h          100 non-null    object
#  4   7d           100 non-null    object
#  5   24Volume     100 non-null    object
#  6   Mkt Cap      100 non-null    object
#  7   FDV          100 non-null    object
#  8   MarktcapFDV  100 non-null    object
# dtypes: object(9)
# memory usage: 7.2+ KB

# %%
# if we want to change the objects to floats it gives an error. We need to remove the $ and % and , signs
# df.iloc[:,1:].astype(float)

# %%
# we can use regular expressions to replance check regex101.com
df = df.replace('[\$\%,]', '', regex=True)

# %%
df.head()
# Out:
#             Coin     Price    1h   24h    7d     24Volume       Mkt Cap  \
# 0    Bitcoin BTC  28919.33   0.0  -1.5  -3.3  23383926918  559386921097
# 1   Ethereum ETH   1954.65   0.2  -2.4   1.8  15145886450  235267461213
# 2    Tether USDT      1.00  -0.1  -0.4  -0.1  39351843271   81374101359
# 3        BNB BNB    325.55   0.1  -1.2   1.6    926550242   51369472670
# 4  USD Coin USDC  0.999955  -0.0  -0.5   0.0   5052260808   31248083356
#
#             FDV MarktcapFDV
# 0  607040903953        0.92
# 1  235267461213        1.00
# 2   81374101359        1.00
# 3   65071483944        0.79
# 4   31248083356        1.00

# %%
# we still have - signs. This gives an error if we want to change the datatype
# df.iloc[:,1:].astype(float) # gives error


#complicated way to approach this 
#create a list (mask) of true false for condition
m_neg = df['1h'].str.contains('-')
m_neg
# Out:
# 0     False
# 1     False
# 2      True
# 3     False
# 4      True
#       ...
# 95     True
# 96     True
# 97    False
# 98    False
# 99    False
# Name: 1h, Length: 100, dtype: bool

# %%
#remove the - sign
df['1h'] = df['1h'].str.replace('-', '')
df.head()
# Out:
#             Coin     Price   1h   24h    7d     24Volume       Mkt Cap  \
# 0    Bitcoin BTC  28919.33  0.0  -1.5  -3.3  23383926918  559386921097
# 1   Ethereum ETH   1954.65  0.2  -2.4   1.8  15145886450  235267461213
# 2    Tether USDT      1.00  0.1  -0.4  -0.1  39351843271   81374101359
# 3        BNB BNB    325.55  0.1  -1.2   1.6    926550242   51369472670
# 4  USD Coin USDC  0.999955  0.0  -0.5   0.0   5052260808   31248083356
#
#             FDV MarktcapFDV
# 0  607040903953        0.92
# 1  235267461213        1.00
# 2   81374101359        1.00
# 3   65071483944        0.79
# 4   31248083356        1.00

# %%
#type cast the object
df['1h'] = df['1h'].astype(float)
# on the True locations, multiply with -1
df.loc[m_neg, "1h"] *= -1 
df.head()
# Out:
#             Coin     Price   1h   24h    7d     24Volume       Mkt Cap  \
# 0    Bitcoin BTC  28919.33  0.0  -1.5  -3.3  23383926918  559386921097
# 1   Ethereum ETH   1954.65  0.2  -2.4   1.8  15145886450  235267461213
# 2    Tether USDT      1.00 -0.1  -0.4  -0.1  39351843271   81374101359
# 3        BNB BNB    325.55  0.1  -1.2   1.6    926550242   51369472670
# 4  USD Coin USDC  0.999955 -0.0  -0.5   0.0   5052260808   31248083356
#
#             FDV MarktcapFDV
# 0  607040903953        0.92
# 1  235267461213        1.00
# 2   81374101359        1.00
# 3   65071483944        0.79
# 4   31248083356        1.00

# %%
# simple solution
# if we use errors='ignore' it does not give an error 
df.iloc[:,1:] = df.iloc[:,1:].astype(float, errors='ignore') # no error
df.head()
# Out:
#             Coin         Price   1h  24h   7d      24Volume       Mkt Cap  \
# 0    Bitcoin BTC  28919.330000  0.0 -1.5 -3.3  2.338393e+10  5.593869e+11
# 1   Ethereum ETH   1954.650000  0.2 -2.4  1.8  1.514589e+10  2.352675e+11
# 2    Tether USDT      1.000000 -0.1 -0.4 -0.1  3.935184e+10  8.137410e+10
# 3        BNB BNB    325.550000  0.1 -1.2  1.6  9.265502e+08  5.136947e+10
# 4  USD Coin USDC      0.999955 -0.0 -0.5  0.0  5.052261e+09  3.124808e+10
#
#             FDV MarktcapFDV
# 0  607040903953        0.92
# 1  235267461213        1.00
# 2   81374101359        1.00
# 3   65071483944        0.79
# 4   31248083356        1.00

# %%
#check if succeeded
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Coin         100 non-null    object
#  1   Price        100 non-null    float64
#  2   1h           100 non-null    float64
#  3   24h          100 non-null    float64
#  4   7d           100 non-null    float64
#  5   24Volume     100 non-null    float64
#  6   Mkt Cap      100 non-null    float64
#  7   FDV          100 non-null    object
#  8   MarktcapFDV  100 non-null    object
# dtypes: float64(6), object(3)
# memory usage: 7.2+ KB

# %%
#something is in the column which blocks the typecasting
df['FDV'].value_counts()
# Out:
# -               22
# 607040903953     1
# 2285509216       1
# 1071118974       1
# 1176348369       1
#                 ..
# 11357733069      1
# 2640177849       1
# 4898742428       1
# 2950243064       1
# 515912447        1
# Name: FDV, Length: 79, dtype: int64

# %%
# it is the - sign (22 times)

# %%
# remove everything which is not a number, or a dot, replace it with NaN and then make it a float
df[['FDV', 'MarktcapFDV']] = df[['FDV', 'MarktcapFDV']].replace('[^0-9.]+', np.nan, regex=True).astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Coin         100 non-null    object
#  1   Price        100 non-null    float64
#  2   1h           100 non-null    float64
#  3   24h          100 non-null    float64
#  4   7d           100 non-null    float64
#  5   24Volume     100 non-null    float64
#  6   Mkt Cap      100 non-null    float64
#  7   FDV          78 non-null     float64
#  8   MarktcapFDV  78 non-null     float64
# dtypes: float64(8), object(1)
# memory usage: 7.2+ KB

# %%
df.head(10)
# Out:
#                       Coin         Price   1h  24h    7d      24Volume  \
# 0              Bitcoin BTC  28919.330000  0.0 -1.5  -3.3  2.338393e+10
# 1             Ethereum ETH   1954.650000  0.2 -2.4   1.8  1.514589e+10
# 2              Tether USDT      1.000000 -0.1 -0.4  -0.1  3.935184e+10
# 3                  BNB BNB    325.550000  0.1 -1.2   1.6  9.265502e+08
# 4            USD Coin USDC      0.999955 -0.0 -0.5   0.0  5.052261e+09
# 5                  XRP XRP      0.495314  0.0  0.1  -2.0  1.889694e+09
# 6              Cardano ADA      0.419258  0.0  1.1   3.4  5.414541e+08
# 7            Dogecoin DOGE      0.091924  0.1  4.1  10.1  1.807889e+09
# 8  Lido Staked Ether STETH   1950.490000  0.1 -2.7   2.0  3.736576e+07
# 9            Polygon MATIC      1.090000  0.1 -1.9  -1.1  5.090229e+08
#
#         Mkt Cap           FDV  MarktcapFDV
# 0  5.593869e+11  6.070409e+11         0.92
# 1  2.352675e+11  2.352675e+11         1.00
# 2  8.137410e+10  8.137410e+10         1.00
# 3  5.136947e+10  6.507148e+10         0.79
# 4  3.124808e+10  3.124808e+10         1.00
# 5  2.559999e+10  4.946780e+10         0.52
# 6  1.467547e+10  1.884422e+10         0.78
# 7  1.280751e+10           NaN          NaN
# 8  1.183395e+10  1.183395e+10         1.00
# 9  1.005949e+10  1.091114e+10         0.92
